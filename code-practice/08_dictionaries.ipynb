# %% [markdown]
# ## Dictionaries

# %%
d = {
    "list" :    "list is a sequence that store elements ",
    "dictionary":"stores definition of something",
    "string":     "something under inverted commas",
    "integer":     "it is a datatype"
}

# %%
d["list"]
# Out:
# 'list is a sequence that store elements '

# %%
d["integer"]
# Out:
# 'it is a datatype'

# %%
d["sequence"] = "something in an oder"

# %%
d
# Out:
# {'list': 'list is a sequence that store elements ',
#  'dictionary': 'stores definition of something',
#  'string': 'something under inverted commas',
#  'integer': 'it is a datatype',
#  'sequence': 'something in an oder'}

# %%
d["dictionary"] = "stores meaningful"

# %%
d
# Out:
# {'list': 'list is a sequence that store elements ',
#  'dictionary': 'stores meaningful',
#  'string': 'something under inverted commas',
#  'integer': 'it is a datatype',
#  'sequence': 'something in an oder'}

# %%
d["random"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 d["random"]
#
# KeyError: 'random'

# %%
for k in d:
    v = d[k]
    print (k, "=", v)
# Out:
# list = list is a sequence that store elements
# dictionary = stores meaningful
# string = something under inverted commas
# integer = it is a datatype
# sequence = something in an oder

# %%
"string"in d
# Out:
# True

# %%
"random" in d
# Out:
# False

# %%
if "home" not in d:
    print ("this keyword is not define")
else:
    print ("keyword found")
# Out:
# this keyword is not define

# %%
d.items()
# Out:
# dict_items([('list', 'list is a sequence that store elements '), ('dictionary', 'stores meaningful'), ('string', 'something under inverted commas'), ('integer', 'it is a datatype'), ('sequence', 'something in an oder')])

# %%
for k, v in d.items():
    print(k, "=", v)
# Out:
# list = list is a sequence that store elements
# dictionary = stores meaningful
# string = something under inverted commas
# integer = it is a datatype
# sequence = something in an oder

# %%
user_profile = {
    'id': 1024,
    'name': 'Ayesha',
    'role': 'Student',
    'email': '--@example.com'
}

print('Welcome', user_profile['name'], '(', user_profile['role'], ')' ,'with email',user_profile['email'])
# Out:
# Welcome Ayesha ( Student ) with email --@example.com

# %%
month_names = {
    1: "January",
    2: "February",
    3: "March",
    12: "December"
}

# %%
month_name["1"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 month_name["1"]
#
# NameError: name 'month_name' is not defined

# %%
month_name[int("1")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 month_name[int("1")]
#
# NameError: name 'month_name' is not defined
