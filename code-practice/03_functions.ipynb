# %% [markdown]
# # Defining Functions

# %%
def square(x):
    return x * x

# %%
y = square(12)

# %%
y
# Out:
# 144

# %%
s * 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s * 3
#
# NameError: name 's' is not defined

# %%
"s" * 3
# Out:
# 'sss'

# %%
y = square("x")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 y = square("x")
#
# Cell In[1], line 2, in square(x)
#       1 def square(x):
# ----> 2     return x * x
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
"s"*"s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 "s"*"s"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
def add(a, b):
    return a + b

# %%
v = add(3, 4)

# %%
v
# Out:
# 7

# %%
def avg(a, b):
    return add(a, b)/2

# %%
y = avg (12,6)

# %%
y
# Out:
# 9.0

# %%
def sqrt(num, guess): 
    print ("Finding square root of", num, "starting with guess:", guess)

# %%
sqrt(48, 1)
# Out:
# Finding square root of 48 starting with guess: 1

# %%
def sqrt(num, guess = 2): 
    print ("Finding square root of", num, "starting with guess:", guess)

# %%
sqrt(48)
# Out:
# Finding square root of 48 starting with guess: 2

# %%
def calculate_volume(l, w, h):
    """calculate amount of three-dimensional (3D) space an object occupies 
    For a standard rectangular box
    l -----length
    w -----width
    h------height
    (this is a doc string)"""
    return l * w * h

# %%
help (calculate_volume)
# Out:
# Help on function calculate_volume in module __main__:
#
# calculate_volume(l, w, h)
#     calculate amount of three-dimensional (3D) space an object occupies
#     For a standard rectangular box
#     l -----length
#     w -----width
#     h------height
#     (this is a doc string)

# %%
calculate_volume(4,2,1)
# Out:
# 8
