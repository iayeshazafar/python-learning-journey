# %% [markdown]
# # **Basic Expression**

# %%
 11
# Out:
# 11

# %%
-2 + 14
# Out:
# 12

# %%
-3 + (12)
# Out:
# 9

# %%
2 -1          -3
# Out:
# -2

# %%
3 / 4
# Out:
# 0.75

# %%
2 % 14
# Out:
# 2

# %%
type(1)
# Out:
# int

# %%
type(4 / 2)
# Out:
# float

# %%
type(2 / 4)
# Out:
# float

# %%
3 * 10
# Out:
# 30

# %%
5 * 6 +13
# Out:
# 43

# %%
5 * ( 6 + 13)
# Out:
# 95

# %% [markdown]
# ## Conditional Expression

# %%
5 > 2
# Out:
# True

# %%
3 > 0
# Out:
# True

# %%
4 < 2
# Out:
# False

# %%
3 == 4
# Out:
# False

# %%
5 >= 4
# Out:
# True

# %%
6 >= 10
# Out:
# False

# %% [markdown]
# ## String Expression

# %%
'abs'
# Out:
# 'abs'

# %%
"abc"
# Out:
# 'abc'

# %%
"""multiline string write multiple lines
in one line 
after \n"""
# Out:
# 'multiline string write multiple lines\nin one line \nafter \n'

# %%
'abc'* 3
# Out:
# 'abcabcabc'

# %%
'xy' + 'za'
# Out:
# 'xyza'

# %%
type('xyz')
# Out:
# str

# %% [markdown]
# ### Bool expression

# %%
type(False)
# Out:
# bool

# %%
False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
not True
# Out:
# False

# %%
True and False or True
# Out:
# True

# %%
True or False and False and True
# Out:
# True

# %% [markdown]
# ### Call Expression

# %%
(True or False) and (False and True)
# Out:
# False

# %%
max(3, 2)
# Out:
# 3

# %%
min (16, 11)
# Out:
# 11

# %%
pow(3, 2)
# Out:
# 9

# %%
max( max(1, -8) , min( pow(3, 5) , -4)    )
# Out:
# 1

# %%
a = [(4.3, 'a'), (3, 'f', -1), (1, '5', 7)]

# %%
type(a[2][1])
# Out:
# str

# %%
type(a[0][0])
# Out:
# float
