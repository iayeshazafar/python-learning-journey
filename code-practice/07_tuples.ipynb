# %% [markdown]
# ## Tuples
# same as list

# %%
blue = (1, 3 ,4, "hi")

# %%
blue
# Out:
# (1, 3, 4, 'hi')

# %%
len(blue)
# Out:
# 4

# %%
blue[1:3]
# Out:
# (3, 4)

# %%
blue[2] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 blue[2] = 3
#
# TypeError: 'tuple' object does not support item assignment
