# %%
mammals  = ['cat', 'monkey', 'horse']
fish = ['turtle', 'shark', 'dolphin']

# %%
animals = [mammals, fish]

# %%
print (animals)
# Out:
# [['cat', 'monkey', 'horse'], ['turtle', 'shark', 'dolphin']]

# %%
mammals[0] = 'mule'

# %%
mammals
# Out:
# ['mule', 'monkey', 'horse']

# %%
animals
# Out:
# [['mule', 'monkey', 'horse'], ['turtle', 'shark', 'dolphin']]

# %%
mammals_2 = mammals

# %%
mammals_2[0] = "dog"

# %%
mammals_2
# Out:
# ['dog', 'monkey', 'horse']

# %%
animals
# Out:
# [['dog', 'monkey', 'horse'], ['turtle', 'shark', 'dolphin']]

# %%
mammals_3 = mammals[:]

# %%
mammals_3
# Out:
# ['dog', 'monkey', 'horse']

# %%
mammals
# Out:
# ['dog', 'monkey', 'horse']

# %%
animals
# Out:
# [['dog', 'monkey', 'horse'], ['turtle', 'shark', 'dolphin']]

# %%
mammals_3[0] = "cat"

# %%
mammals_3
# Out:
# ['cat', 'monkey', 'horse']

# %%
mammals
# Out:
# ['dog', 'monkey', 'horse']

# %%
animals
# Out:
# [['dog', 'monkey', 'horse'], ['turtle', 'shark', 'dolphin']]

# %%
s1 = ['student 1', 'Ali', 'Khan']
s2 = ['student 2', 'Zia', 'Farooq']
s3 = ['student 3', 'Hadi', 'Zaman']

# %%
students = [s1, s2, s3]
print (students)
# Out:
# [['student 1', 'Ali', 'Khan'], ['student 2', 'Zia', 'Farooq'], ['student 3', 'Hadi', 'Zaman']]

# %%
students_copy = students[:]

# %%
students_copy
# Out:
# [['student 1', 'Ali', 'Khan'],
#  ['student 2', 'Zia', 'Farooq'],
#  ['student 3', 'Hadi', 'Zaman']]

# %%
students_copy[0][0] = 'student 1 changed'

# %%
students_copy
# Out:
# [['student 1 changed', 'Ali', 'Khan'],
#  ['student 2', 'Zia', 'Farooq'],
#  ['student 3', 'Hadi', 'Zaman']]

# %%
s1
# Out:
# ['student 1 changed', 'Ali', 'Khan']

# %%
import copy

# %%
students_3 = copy.deepcopy(students)

# %%
students_3[0][0] = 'student 1 changed again'

# %%
students_3
# Out:
# [['student 1 changed again', 'Ali', 'Khan'],
#  ['student 2', 'Zia', 'Farooq'],
#  ['student 3', 'Hadi', 'Zaman']]

# %%
students
# Out:
# [['student 1 changed', 'Ali', 'Khan'],
#  ['student 2', 'Zia', 'Farooq'],
#  ['student 3', 'Hadi', 'Zaman']]
